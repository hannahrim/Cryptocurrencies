# %%
# !pip install scikit-learn
# !pip install plotly
# !pip install pyviz 
# !pip install hvplot
# Out:
# ...
#      |████████████████████████████████| 16.4 MB 4.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.5 MB 4.0 MB/s eta 0:00:01     |███████████████                 | 7.3 MB 8.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 764 kB 5.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 36.6 MB 779 kB/s eta 0:00:011
#     ERROR: Command errored out with exit status 1:
# ...

# %%
import pandas as pd

# %%
file_path = "/Users/hannahrim/Desktop/Class/Cryptocurrencies/iris.csv"
iris_df = pd.read_csv(file_path)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
